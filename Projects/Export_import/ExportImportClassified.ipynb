# %%
import zipfile
import os

# Path to the uploaded zip file (replace 'your_zip_file.zip' with the actual filename)
zip_file_path = r'C:\Users\chaitanya\trails\wits_en_trade_summary_allcountries_allyears.zip'

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall('extracted_files')

# List all files in the extracted directory
extracted_files = os.listdir('extracted_files')
print(extracted_files)
# Out:
# ['en_ABW_AllYears_WITS_Trade_Summary.CSV', 'en_AFG_AllYears_WITS_Trade_Summary.CSV', 'en_AGO_AllYears_WITS_Trade_Summary.CSV', 'en_AIA_AllYears_WITS_Trade_Summary.CSV', 'en_ALB_AllYears_WITS_Trade_Summary.CSV', 'en_AND_AllYears_WITS_Trade_Summary.CSV', 'en_ANT_AllYears_WITS_Trade_Summary.CSV', 'en_ARE_AllYears_WITS_Trade_Summary.CSV', 'en_ARG_AllYears_WITS_Trade_Summary.CSV', 'en_ARM_AllYears_WITS_Trade_Summary.CSV', 'en_ATG_AllYears_WITS_Trade_Summary.CSV', 'en_AUS_AllYears_WITS_Trade_Summary.CSV', 'en_AUT_AllYears_WITS_Trade_Summary.CSV', 'en_AZE_AllYears_WITS_Trade_Summary.CSV', 'en_BDI_AllYears_WITS_Trade_Summary.CSV', 'en_BEL_AllYears_WITS_Trade_Summary.CSV', 'en_BEN_AllYears_WITS_Trade_Summary.CSV', 'en_BFA_AllYears_WITS_Trade_Summary.CSV', 'en_BGD_AllYears_WITS_Trade_Summary.CSV', 'en_BGR_AllYears_WITS_Trade_Summary.CSV', 'en_BHR_AllYears_WITS_Trade_Summary.CSV', 'en_BHS_AllYears_WITS_Trade_Summary.CSV', 'en_BIH_AllYears_WITS_Trade_Summary.CSV', 'en_BLR_AllYears_WITS_Trade_Sum
# ...

# %%
import zipfile
import pandas as pd

# Path to the zip file
zip_file_path = r'C:\Users\chaitanya\trails\wits_en_trade_summary_allcountries_allyears.zip'

# List of files to read from the zip
csv_files = [
    'en_ABW_AllYears_WITS_Trade_Summary.CSV',
    'en_AFG_AllYears_WITS_Trade_Summary.CSV',
    'en_AGO_AllYears_WITS_Trade_Summary.CSV'
]

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    for csv_file in csv_files:
        # Open each CSV file within the zip
        with zip_ref.open(csv_file) as file:
            # Read the CSV file into a pandas DataFrame
            df = pd.read_csv(file, encoding='ISO-8859-1')

            # Display the first few rows of the DataFrame
            print(f"Contents of {csv_file}:")
            print(df.head())
            print("\n" + "-"*50 + "\n")
# Out:
# Contents of en_ABW_AllYears_WITS_Trade_Summary.CSV:
#   Reporter Partner Product categories Indicator Type        Indicator   2021  \
# 0    Aruba   World     Consumer goods         Export  Export(US$ Mil)  74.47
# 1    Aruba   World           Minerals         Export  Export(US$ Mil)   0.00
# 2    Aruba   World      Raw materials         Export  Export(US$ Mil)   3.46
# 3    Aruba   World      Capital goods         Export  Export(US$ Mil)   5.43
# 4    Aruba   World  Plastic or Rubber         Export  Export(US$ Mil)   0.62
#
#     2020   2019   2018   2017  ...  1997  1996  1995  1994  1993  1992  1991  \
# 0  52.20  59.37  50.39  61.93  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   0.01   0.00   0.01   0.00  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3.00   4.65   4.64  15.33  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.39   8.51   6.66   5.77  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
import zipfile
import pandas as pd

# Path to the zip file
zip_file_path = r'C:\Users\chaitanya\trails\wits_en_trade_summary_allcountries_allyears.zip'

# List of files to read from the zip
csv_files = [
    'en_ABW_AllYears_WITS_Trade_Summary.CSV',
    'en_AFG_AllYears_WITS_Trade_Summary.CSV',
    'en_AGO_AllYears_WITS_Trade_Summary.CSV'
]

# List to hold DataFrames
dfs = []

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    for csv_file in csv_files:
        # Open each CSV file within the zip
        with zip_ref.open(csv_file) as file:
            # Read the CSV file into a pandas DataFrame and append it to the list
            df = pd.read_csv(file, encoding='ISO-8859-1')
            dfs.append(df)

# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the combined DataFrame
print(combined_df.head())
# Out:
#   Reporter Partner Product categories Indicator Type        Indicator   2021  \
# 0    Aruba   World     Consumer goods         Export  Export(US$ Mil)  74.47
# 1    Aruba   World           Minerals         Export  Export(US$ Mil)   0.00
# 2    Aruba   World      Raw materials         Export  Export(US$ Mil)   3.46
# 3    Aruba   World      Capital goods         Export  Export(US$ Mil)   5.43
# 4    Aruba   World  Plastic or Rubber         Export  Export(US$ Mil)   0.62
#
#     2020   2019   2018   2017  ...  1997  1996  1995  1994  1993  1992  1991  \
# 0  52.20  59.37  50.39  61.93  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   0.01   0.00   0.01   0.00  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3.00   4.65   4.64  15.33  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.39   8.51   6.66   5.77  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   0.57   0.38   0.57   0.57  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1990  1989  1988
# ...

# %%
import zipfile
import pandas as pd

# Path to the zip file
zip_file_path = r'C:\Users\chaitanya\trails\wits_en_trade_summary_allcountries_allyears.zip'

# List to hold DataFrames
dfs = []

# Open the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Loop through all files in the zip archive
    for file_name in zip_ref.namelist():
        # Check if the file is a CSV file
        if file_name.endswith('.CSV'):
            # Open and read the CSV file into a pandas DataFrame
            with zip_ref.open(file_name) as file:
                df = pd.read_csv(file, encoding='ISO-8859-1')
                dfs.append(df)

# Combine all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the combined DataFrame
print(combined_df.head())
# Out:
#   Reporter Partner Product categories Indicator Type        Indicator   2021  \
# 0    Aruba   World     Consumer goods         Export  Export(US$ Mil)  74.47
# 1    Aruba   World           Minerals         Export  Export(US$ Mil)   0.00
# 2    Aruba   World      Raw materials         Export  Export(US$ Mil)   3.46
# 3    Aruba   World      Capital goods         Export  Export(US$ Mil)   5.43
# 4    Aruba   World  Plastic or Rubber         Export  Export(US$ Mil)   0.62
#
#     2020   2019   2018   2017  ...  1997  1996  1995  1994  1993  1992  1991  \
# 0  52.20  59.37  50.39  61.93  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   0.01   0.00   0.01   0.00  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3.00   4.65   4.64  15.33  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.39   8.51   6.66   5.77  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   0.57   0.38   0.57   0.57  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1990  1989  1988
# ...

# %%
#use this code to save specific conditions data and watch specific conditions of a data


# Specify the output file path
output_file_path = r'F:\Chrome_Downloads\combined_data.csv'

# Export the DataFrame to a CSV file
combined_df.to_csv(output_file_path, index=False)

print(f"Data has been exported to {output_file_path}")
# Out:
# Data has been exported to F:\Chrome_Downloads\combined_data.csv

# %%
combined_df.head()
# Out:
#   Reporter Partner Product categories Indicator Type        Indicator   2021  \
# 0    Aruba   World     Consumer goods         Export  Export(US$ Mil)  74.47
# 1    Aruba   World           Minerals         Export  Export(US$ Mil)   0.00
# 2    Aruba   World      Raw materials         Export  Export(US$ Mil)   3.46
# 3    Aruba   World      Capital goods         Export  Export(US$ Mil)   5.43
# 4    Aruba   World  Plastic or Rubber         Export  Export(US$ Mil)   0.62
#
#     2020   2019   2018   2017  ...  1997  1996  1995  1994  1993  1992  1991  \
# 0  52.20  59.37  50.39  61.93  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   0.01   0.00   0.01   0.00  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   3.00   4.65   4.64  15.33  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.39   8.51   6.66   5.77  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   0.57   0.38   0.57   0.57  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1990  1989  1988
# ...

# %%
combined_df.columns
# Out:
# Index(['Reporter', 'Partner', 'Product categories', 'Indicator Type',
#        'Indicator', '2021', '2020', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006',
#        '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997',
#        '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(14, 10))
axes = axes.flat
columnas_numeric = df.select_dtypes(include=['float64', 'int64']).columns

for i, colum in enumerate(columnas_numeric):
    sns.histplot(
        data    = df,
        x       = colum,
        stat    = "count",
        kde     = True,
        color   = (list(plt.rcParams['axes.prop_cycle'])*2)[i]["color"],
        line_kws= {'linewidth': 2},
        alpha   = 0.3,
        ax      = axes[i]
    )
    axes[i].set_title(colum, fontsize = 9, fontweight = "bold")
    axes[i].tick_params(labelsize = 8)
    axes[i].set_xlabel("")
    
    
fig.tight_layout()
plt.subplots_adjust(top = 0.9)
fig.suptitle('Distribución variables numéricas', fontsize = 14, fontweight = "bold");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 16
#       5 columnas_numeric = df.select_dtypes(include=['float64', 'int64']).columns
#       7 for i, colum in enumerate(columnas_numeric):
#       8     sns.histplot(
#       9         data    = df,
#      10         x       = colum,
#      11         stat    = "count",
#      12         kde     = True,
#      13         color   = (list(plt.rcParams['axes.prop_cycle'])*2)[i]["color"],
#      14         line_kws= {'linewidth': 2},
#      15         alpha   = 0.3,
# ---> 16         ax      = axes[i]
#      17     )
#      18     axes[i].set_title(colum, fontsize = 9, fontweight = "bold")
#      19     axes[i].tick_params(labelsize = 8)
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
combined_df['Indicator'].unique
# Out:
# <bound method Series.unique of 0                            Export(US$ Mil)
# 1                            Export(US$ Mil)
# 2                            Export(US$ Mil)
# 3                            Export(US$ Mil)
# 4                            Export(US$ Mil)
#                        ...
# 353    Partner share(%)-Top 5 Export Partner
# 354                  Export Product share(%)
# 355    Partner share(%)-Top 5 Export Partner
# 356                  Export Product share(%)
# 357                  Import Product share(%)
# Name: Indicator, Length: 358, dtype: object>

# %%
EI = combined_df[combined_df['Indicator'].isin(['Export(US$ Mil)', 'Import(US$ Mil)'])]

# %%
EI .head(50)
# Out:
#         Reporter Partner     Product categories Indicator Type  \
# 0          Aruba   World         Consumer goods         Export
# 1          Aruba   World               Minerals         Export
# 2          Aruba   World          Raw materials         Export
# 3          Aruba   World          Capital goods         Export
# 4          Aruba   World      Plastic or Rubber         Export
# 6          Aruba   World              Vegetable         Export
# 9          Aruba   World               Footwear         Export
# 11         Aruba   World          Miscellaneous         Export
# 15         Aruba   World     Intermediate goods         Export
# 16         Aruba   World  Textiles and Clothing         Export
# 17         Aruba   World          Food Products         Export
# 19         Aruba   World         Consumer goods         Import
# 21         Aruba   World         Transportation         Export
# 24         Aruba   World          Raw materials         Import
# ...

# %%
#country wise average of imp/exp 

EI_avg = combined_df[combined_df['Indicator'].isin(['Exports (in US$ Mil)', 'Imports(in US$ Mil)'])]
EI_avg.head(10)
# Out:
#         Reporter Partner Product categories Indicator Type  \
# 47         Aruba   World       All Products         Export
# 162  Afghanistan   World       All Products         Export
# 285       Angola   World       All Products         Export
#
#                 Indicator      2021      2020      2019      2018      2017  \
# 47   Exports (in US$ Mil)     88.35     65.93     78.64     69.47     88.83
# 162  Exports (in US$ Mil)       NaN       NaN    870.49    884.50    831.93
# 285  Exports (in US$ Mil)  34472.16  22134.51  35432.45  40664.72  34904.88
#
#      ...  1997  1996  1995  1994  1993  1992  1991  1990  1989  1988
# 47   ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 162  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 285  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [3 rows x 39 columns]

# %%
#top 5 partners details
EI_Top5_partners=combined_df[combined_df['Indicator'].isin(['Trade (US$ Mil)-Top 5 Export Partner', 'Trade (US$ Mil)-Top 5 Import Partner'])]
EI_Top5_partners.head(10)
# Out:
#    Reporter               Partner Product categories Indicator Type  \
# 5     Aruba        United Kingdom       All Products         Import
# 7     Aruba                Panama       All Products         Export
# 8     Aruba  Netherlands Antilles       All Products         Import
# 10    Aruba  Netherlands Antilles       All Products         Export
# 18    Aruba               Curaçao       All Products         Export
# 20    Aruba           Unspecified       All Products         Export
# 22    Aruba               Finland       All Products         Import
# 23    Aruba                 China       All Products         Import
# 25    Aruba           Netherlands       All Products         Import
# 26    Aruba              Colombia       All Products         Export
#
#                                Indicator    2021    2020    2019    2018  \
# 5   Trade (US$ Mil)-Top 5 Import Partner     NaN     NaN     NaN     NaN
# ...

# %%
#top 5 partners %
EI_Top5_partnersshare=combined_df[combined_df['Indicator'].isin(['Partner share(%)-Top 5 Export Partner', 'Partner share(%)-Top 5 Import Partner'])]
EI_Top5_partnersshare.head()
# Out:
#    Reporter         Partner Product categories Indicator Type  \
# 56    Aruba        Colombia       All Products         Import
# 57    Aruba   United States       All Products         Import
# 60    Aruba        Colombia       All Products         Export
# 64    Aruba     Netherlands       All Products         Import
# 67    Aruba  United Kingdom       All Products         Import
#
#                                 Indicator   2021   2020   2019   2018   2017  \
# 56  Partner share(%)-Top 5 Import Partner    NaN    NaN    NaN    NaN   2.33
# 57  Partner share(%)-Top 5 Import Partner  50.80  52.47  53.15  56.81  55.47
# 60  Partner share(%)-Top 5 Export Partner  49.43  14.48    NaN  21.46  19.98
# 64  Partner share(%)-Top 5 Import Partner  15.55  15.43  12.90  12.64  12.97
# 67  Partner share(%)-Top 5 Import Partner    NaN    NaN    NaN    NaN    NaN
#
#     ...  1997  1996  1995  1994  1993  1992  1991  1990  1989  1988
# ...

# %%
#No of import/export products
EI_Products=combined_df[combined_df['Indicator'].isin(['No. Of Export products', 'No. Of Import products'])]
EI_Products.head()
# Out:
#         Reporter Partner Product categories Indicator Type  \
# 12         Aruba     ...                ...         Import
# 13         Aruba     ...                ...         Export
# 123  Afghanistan     ...                ...         Import
# 125  Afghanistan     ...                ...         Export
# 242       Angola     ...                ...         Import
#
#                   Indicator    2021    2020    2019    2018    2017  ...  \
# 12   No. Of Import products  3414.0  3354.0  3399.0  3413.0  3385.0  ...
# 13   No. Of Export products   895.0   825.0   881.0   941.0   985.0  ...
# 123  No. Of Import products     NaN     NaN   741.0   331.0   221.0  ...
# 125  No. Of Export products     NaN     NaN   204.0   156.0    99.0  ...
# 242  No. Of Import products  4033.0  4003.0  4106.0  4075.0  4103.0  ...
#
#      1997  1996  1995  1994  1993  1992  1991  1990  1989  1988
# 12    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
Remaining records
# Define the list of conditions to filter out
exclude_conditions = [
    'No. Of Export products', 'No. Of Import products',
    'Trade (US$ Mil)-Top 5 Import Partner', 'Trade (US$ Mil)-Top 5 Export Partner',
    'Partner share(%)-Top 5 Export Partner', 'Partner share(%)-Top 5 Import Partner',
    'Exports (in US$ Mil)', 'Imports(in US$ Mil)',
    'Export(US$ Mil)', 'Import(US$ Mil)'
]

# Filter the DataFrame to get the remaining records
EI_remaining = combined_df[~combined_df['Indicator'].isin(exclude_conditions)]

# Display the first few rows of the resulting DataFrame
EI_remaining.head()
# Out:
#    Reporter Partner Product categories Indicator Type  \
# 14    Aruba     ...                ...         Export
# 31    Aruba     ...                ...    Development
# 32    Aruba     ...                ...         Tariff
# 36    Aruba     ...                ...    Development
# 39    Aruba   World       All Products         Tariff
#
#                            Indicator      2021  2020       2019       2018  \
# 14            No. Of Export partners      10.0  10.0      10.00      10.00
# 31   Trade Balance (current US$ Mil)       NaN   NaN        NaN     -26.48
# 32           No. Of Tariff Agreement       1.0   NaN       1.00       1.00
# 36             GDP (current US$ Mil)       NaN   NaN        NaN    3202.19
# 39  Duty Free Imports (US$ Thousand)  162509.2   NaN  161625.99  161625.99
#
#          2017  ...     1997     1996     1995     1994     1993    1992  \
# 14      10.00  ...      NaN      NaN      NaN      NaN      NaN     NaN
# ...
