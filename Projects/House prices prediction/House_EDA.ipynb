# %%
import pandas as pd
House = pd.read_csv("C:\\Users\\chaitanya\\81 column dataset.csv")
House.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
House.shape
# Out:
# (1460, 81)

# %%
House_duplicated=House.duplicated().value_counts()
House_duplicated.head()
# Out:
# False    1460
# Name: count, dtype: int64

# %%
House.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
House.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
import pandas as pd

# Assuming 'categorical1' is your DataFrame
null_counts = House.isnull().sum()
null_counts_percentage = (House.isnull().sum() / len(House)) * 100
data_types = House.dtypes

# Combine the null counts, null percentages, and data types into a single DataFrame
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Null counts%': null_counts_percentage,
    'Data Type': data_types
})

# Sort by 'Null counts%' in descending order
combined_info = combined_info.sort_values(by='Null counts%', ascending=False)

# Display the combined DataFrame
print(combined_info)
# Out:
#              Null Count  Null counts% Data Type
# PoolQC             1453     99.520548    object
# MiscFeature        1406     96.301370    object
# Alley              1369     93.767123    object
# Fence              1179     80.753425    object
# MasVnrType          872     59.726027    object
# ...                 ...           ...       ...
# ExterQual             0      0.000000    object
# Exterior2nd           0      0.000000    object
# Exterior1st           0      0.000000    object
# RoofMatl              0      0.000000    object
# SalePrice             0      0.000000     int64
#
# [81 rows x 3 columns]

# %%
#looking for special characters
House_cols = ['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice']
       

for cat in House_cols:
    print(f'columns Name : {cat}')
    print(House[cat].value_counts())
    print('==============================================')
# Out:
# columns Name : Id
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: count, Length: 1460, dtype: int64
# ...
# columns Name : MSSubClass
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64
# ...
# columns Name : MSZoning
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# ...
# columns Name : LotFrontage
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64
# ...
# columns Name : LotArea
# LotArea
# 7200     25
# 9600     24
# 6000     17
# 9000     14
# 8400     14
#          ..
# 14601     1
# ...

# %%
#automated but not sure caluculations are correct
from autoviz.AutoViz_Class import AutoViz_Class

# Assuming corr_table_output is your existing DataFrame
# %matplotlib inline
AV = AutoViz_Class()

# Applying AutoViz to your existing DataFrame
dft = AV.AutoViz(
    filename="",  # filename is kept empty since we're passing a DataFrame
    dfte=House,  # your existing DataFrame
    depVar='SalePrice' # target variable, adjust as needed
)
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (1460, 81)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  31
#     Number of String-Categorical Columns =  37
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
# ...

# %%
-------NUMERICAL------------------

# %%
import numpy as np
Numerical_1= House.select_dtypes(include=[np.number])
Numerical_1.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1      60         65.0        8450        7            5         2003
# 1   2      20         80.0        9600        6            8         1976
# 2   3      60         68.0       11250        7            5         2001
# 3   4      70         60.0        9550        7            5         1915
# 4   5      60         84.0       14260        8            5         2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      2003         196.0        706          0         150         856
# 1      1976           0.0        978          0         284        1262
# 2      2002         162.0        486          0         434         920
# 3      1970           0.0        216          0         540         756
# 4      2000         350.0        655          0         490        1145
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# ...

# %%
import pandas as pd

# Assuming 'Numerical_1' is your DataFrame
null_counts =  Numerical_1.isnull().sum()
null_counts_percentage = ( Numerical_1.isnull().sum() / len(Numerical_1)) * 100
data_types =  Numerical_1.dtypes
# Combine the null counts, null percentages, and data types into a single DataFrame
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Null counts%': null_counts_percentage,
    'Data Type': data_types
})

# Sort by 'Null counts%' in descending order
combined_info = combined_info.sort_values(by='Null counts%', ascending=False)

# Display the combined DataFrame
print(combined_info)
# Out:
#                Null Count  Null counts% Data Type
# LotFrontage        259       17.739726    float64
# GarageYrBlt         81        5.547945    float64
# MasVnrArea           8        0.547945    float64
# Id                   0        0.000000      int64
# OpenPorchSF          0        0.000000      int64
# KitchenAbvGr         0        0.000000      int64
# TotRmsAbvGrd         0        0.000000      int64
# Fireplaces           0        0.000000      int64
# GarageCars           0        0.000000      int64
# GarageArea           0        0.000000      int64
# WoodDeckSF           0        0.000000      int64
# EnclosedPorch        0        0.000000      int64
# HalfBath             0        0.000000      int64
# 3SsnPorch            0        0.000000      int64
# ScreenPorch          0        0.000000      int64
# PoolArea             0        0.000000      int64
# MiscVal              0        0.000000      int64
# MoSold               0        0.000000      int64
# ...

# %%
for hc in ["LotFrontage", "GarageYrBlt", "MasVnrArea"]:
    print(hc)
    print("Mean:", Numerical_1[hc].mean())
    print("skewness:",Numerical_1[hc].skew())
    print("Median:", Numerical_1[hc].median())
    print("75th Percentile:", Numerical_1[hc].quantile(0.75))
    print("&&&&&&&&&&&&&&&&&&&&&&&&&&")
# Out:
# LotFrontage
# Mean: 70.04995836802665
# skewness: 2.163569142324884
# Median: 69.0
# 75th Percentile: 80.0
# &&&&&&&&&&&&&&&&&&&&&&&&&&
# GarageYrBlt
# Mean: 1978.5061638868744
# skewness: -0.6494146238714679
# Median: 1980.0
# 75th Percentile: 2002.0
# &&&&&&&&&&&&&&&&&&&&&&&&&&
# MasVnrArea
# Mean: 103.68526170798899
# skewness: 2.669084210182863
# Median: 0.0
# 75th Percentile: 166.0
# &&&&&&&&&&&&&&&&&&&&&&&&&&

# %%
#improve the size of graphs for more quality

# Set up the matplotlib figure
plt.figure(figsize=(18, 6))

# Plot for 'LotFrontage'
plt.subplot(1, 3, 1)
sns.histplot(x='LotFrontage', data=Numerical_1, kde=True, bins=40, color='skyblue')
plt.title('Distribution of LotFrontage')
plt.xlabel('LotFrontage', fontsize=25)
plt.ylabel('Frequency', fontsize=25)


# Plot for 'GarageYrBlt'
plt.subplot(1, 3, 2)
sns.histplot(x='GarageYrBlt', data=Numerical_1, kde=True, bins=40, color='salmon')
plt.title('Distribution of GarageYrBlt')

# Plot for 'MasVnrArea'
plt.subplot(1, 3, 3)
sns.histplot(x='MasVnrArea', data=Numerical_1, kde=True, bins=40, color='lightgreen')
plt.title('Distribution of MasVnrArea')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
??why median,why not mean
i know mean is deviating ,mean will come to picture when not disturbed ,else use median
how do we know mean is getting disturbed

# %%
Numerical_1.describe().transpose()
# Out:
#                 count      mean            std        min       25%     \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %%
#looking for special characters
Numerical_cols = ['Id', 'MSSubClass', 'LotArea', 'OverallCond', 'BsmtFinSF2', 'BsmtUnfSF',
       'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
       

for cat in Numerical_cols:
    print(f'columns Name : {cat}')
    print(House[cat].value_counts())
    print('==============================================')
# Out:
# columns Name : Id
# Id
# 1       1
# 982     1
# 980     1
# 979     1
# 978     1
#        ..
# 485     1
# 484     1
# 483     1
# 482     1
# 1460    1
# Name: count, Length: 1460, dtype: int64
# ...
# columns Name : MSSubClass
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64
# ...
# columns Name : LotArea
# LotArea
# 7200     25
# 9600     24
# 6000     17
# 9000     14
# 8400     14
#          ..
# 14601     1
# 13682     1
# 4058      1
# 17104     1
# 9717      1
# Name: count, Length: 1073, dtype: int64
# ...
# columns Name : OverallCond
# OverallCond
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: count, dtype: int64
# ...
# columns Name : BsmtFinSF2
# BsmtFinSF2
# 0       1293
# 180        5
# 374        3
# 551        2
# 147        2
# 294        2
# ...

# %%
# Function to check if a value is not numeric and not a specific unwanted string
def is_not_numeric(value):
    # Define unwanted strings
    unwanted_strings = {"False", "NaN", "True"}
    
    # Check if value is not numeric and not an unwanted string
    if isinstance(value, (int, float, np.number)):
        return False
    elif isinstance(value, str) and value in unwanted_strings:
        return False
    else:
        return True

# Applying the function to the DataFrame
non_numeric_mask = Numerical_1.applymap(is_not_numeric)

# Printing the mask of non-numeric values
print("Mask of Non-Numeric Values:")
print(non_numeric_mask)

# Optionally, filter out non-numeric values
non_numeric_df = Numerical_1.where(non_numeric_mask, other=np.nan)
print("\nNon-Numeric Values in DataFrame:")
print(non_numeric_df)
# Out:
# Mask of Non-Numeric Values:
#        Id    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     False     False       False      False      False        False
# 1     False     False       False      False      False        False
# 2     False     False       False      False      False        False
# 3     False     False       False      False      False        False
# 4     False     False       False      False      False        False
# ...     ...         ...          ...      ...          ...          ...
# 1455  False     False       False      False      False        False
# 1456  False     False       False      False      False        False
# 1457  False     False       False      False      False        False
# 1458  False     False       False      False      False        False
# 1459  False     False       False      False      False        False
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
(Numerical_1.astype(str) == '?').any()
# Out:
# Id               False
# MSSubClass       False
# LotFrontage      False
# LotArea          False
# OverallQual      False
# OverallCond      False
# YearBuilt        False
# YearRemodAdd     False
# MasVnrArea       False
# BsmtFinSF1       False
# BsmtFinSF2       False
# BsmtUnfSF        False
# TotalBsmtSF      False
# 1stFlrSF         False
# 2ndFlrSF         False
# LowQualFinSF     False
# GrLivArea        False
# BsmtFullBath     False
# BsmtHalfBath     False
# FullBath         False
# HalfBath         False
# BedroomAbvGr     False
# KitchenAbvGr     False
# TotRmsAbvGrd     False
# Fireplaces       False
# GarageYrBlt      False
# GarageCars       False
# GarageArea       False
# WoodDeckSF       False
# OpenPorchSF      False
# EnclosedPorch    False
# 3SsnPorch        False
# ScreenPorch      False
# PoolArea         False
# MiscVal          False
# MoSold           False
# YrSold           False
# SalePrice        False
# dtype: bool

# %%
Numerical_1 = Numerical_1.replace('?', pd.NA).dropna()

# %%
(Numerical_1 .astype(str) == '?').any()

# %%
#save as excel file
import pandas as pd

# Assuming Numerical_1 is your DataFrame
# Specify the path where you want to save the file
file_path = r'F:\jupyter\Numerical_1.xlsx'

# Save the DataFrame as an Excel file
Numerical_1.to_excel(file_path, index=False)

print(f"DataFrame saved to {file_path}")

# %%
Numerical_1['LotFrontage'].fillna(Numerical_1['LotFrontage'].mean(), inplace=True)

Numerical_1['GarageYrBlt'].fillna(Numerical_1['GarageYrBlt'].median() , inplace =True)

Numerical_1['MasVnrArea'].fillna(Numerical_1['MasVnrArea'].median(), inplace= True)

# %%
#testing  null values from imputations
import pandas as pd

# Assuming 'Numerical_1' is your DataFrame
null_counts =  Numerical_1.isnull().sum()
null_counts_percentage = ( Numerical_1.isnull().sum() / len(Numerical_1)) * 100
data_types =  Numerical_1.dtypes
# Combine the null counts, null percentages, and data types into a single DataFrame
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Null counts%': null_counts_percentage,
    'Data Type': data_types
})

# Sort by 'Null counts%' in descending order
combined_info = combined_info.sort_values(by='Null counts%', ascending=False)

# Display the combined DataFrame
print(combined_info)
# Out:
#                Null Count  Null counts% Data Type
# Id                  0           0.0         int64
# WoodDeckSF          0           0.0         int64
# BedroomAbvGr        0           0.0         int64
# KitchenAbvGr        0           0.0         int64
# TotRmsAbvGrd        0           0.0         int64
# Fireplaces          0           0.0         int64
# GarageYrBlt         0           0.0       float64
# GarageCars          0           0.0         int64
# GarageArea          0           0.0         int64
# OpenPorchSF         0           0.0         int64
# MSSubClass          0           0.0         int64
# EnclosedPorch       0           0.0         int64
# 3SsnPorch           0           0.0         int64
# ScreenPorch         0           0.0         int64
# PoolArea            0           0.0         int64
# MiscVal             0           0.0         int64
# MoSold              0           0.0         int64
# YrSold              0           0.0         int64
# ...

# %%
Numerical_1.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
import pandas as pd

# List of features to filter
features = ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
            'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
            'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
            'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
            'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
            'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
            'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
            'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# Calculate the 25th and 75th percentiles for each feature
Q1 = Numerical_1[features].quantile(0.25)
Q3 = Numerical_1[features].quantile(0.75)

# Apply the filter: Keep rows where all features lie within their respective Q1 and Q3
filtered_data = Numerical_1[(Numerical_1[features] >= Q1) & (Numerical_1[features] <= Q3)]

# Display the filtered DataFrame
print(filtered_data)
# Out:
#       Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0    NaN     60.0        65.0       8450.0      7.0          5.0
# 1    NaN     20.0         NaN       9600.0      6.0          NaN
# 2    NaN     60.0        68.0      11250.0      7.0          5.0
# 3    NaN     70.0        60.0       9550.0      7.0          5.0
# 4    NaN     60.0         NaN          NaN      NaN          5.0
# ...   ..         ...          ...      ...          ...          ...
# 1455 NaN     60.0        62.0       7917.0      6.0          5.0
# 1456 NaN     20.0         NaN          NaN      6.0          6.0
# 1457 NaN     70.0        66.0       9042.0      7.0          NaN
# 1458 NaN     20.0        68.0       9717.0      5.0          6.0
# 1459 NaN     20.0        75.0       9937.0      5.0          6.0
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         NaN       2003.0          NaN       706.0        0.0         NaN
# ...

# %%
Numerical_1.shape
# Out:
# (1460, 38)

# %%
filtered_data.shape
# Out:
# (1460, 38)

# %%
-------CATEGORICAL-----------------------------

# %%
categorical1=House.select_dtypes(include=[object])
categorical1.head()

# %%
categorical1.shape

# %%
import pandas as pd

# Assuming 'House' is your DataFrame
null_counts = categorical1.isnull().sum().sort_values(ascending=False)
null_counts_percentage = categorical1.isnull().sum()/len(categorical1)*100
data_types = categorical1.dtypes

# Combine the two into a single DataFrame and align by the sorted null counts index
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Null counts%' : null_counts_percentage,
    'Data Type': data_types[null_counts_percentage.index]  # Align with the sorted null counts
})

# Sort by 'Null counts%' in descending order
combined_info = combined_info.sort_values(by='Null counts%', ascending=False)

# Display the combined DataFrame
print(combined_info)

# %%
# Assuming 'categorical1' is your DataFrame
summary = categorical1.describe().transpose()

# Sorting the summary DataFrame by the 'count' column in ascending order
sorted_summary = summary.sort_values(by='count', ascending=True)

# Display the sorted DataFrame
print(sorted_summary)

# %%
#looking for special characters
Categorical_cols = ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']
   

for cat in Categorical_cols:
    print(f'columns Name : {cat}')
    print(categorical1[cat].value_counts())
    print('==============================================')

# %%
(categorical1.astype(str) == '?').any()

# %%
##categorical1= categorical1.replace('?', pd.NA).dropna()

# %%
(categorical1.astype(str) == '?').any()

# %%
import pandas as pd

# Assuming Categorical1 is your DataFrame
# Specify the path where you want to save the file
file_path = r'F:\jupyter\categorical1.xlsx'

# Save the DataFrame as an Excel file
categorical1.to_excel(file_path, index=False)

print(f"DataFrame saved to {file_path}")

# %%
categorical1[['PoolQC', 'Fence', 'MiscFeature','Alley','FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond','BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2','Electrical']]

# %%
for hc in [['PoolQC', 'Fence', 'MiscFeature','Alley','FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond','BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2','Electrical']]:
    print(hc)
    print("Mode:", categorical1[hc].mode())

# %%
categorical1[['PoolQC', 'Fence', 'MiscFeature', 'Alley', 'FireplaceQu', 'GarageType', 
              'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtQual', 'BsmtCond', 
              'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical','MasVnrType']] = (
    categorical1[['PoolQC', 'Fence', 'MiscFeature', 'Alley', 'FireplaceQu', 
                   'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
                   'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
                   'BsmtFinType2', 'Electrical','MasVnrType']]
    .apply(lambda x: x.fillna(x.mode()[0]))
)

# %%
import pandas as pd

# Assuming 'House' is your DataFrame
null_counts = categorical1.isnull().sum().sort_values(ascending=False)
null_counts_percentage = categorical1.isnull().sum()/len(categorical1)*100
data_types = categorical1.dtypes

# Combine the two into a single DataFrame and align by the sorted null counts index
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Null counts%' : null_counts_percentage,
    'Data Type': data_types[null_counts_percentage.index]  # Align with the sorted null counts
})

# Sort by 'Null counts%' in descending order
combined_info = combined_info.sort_values(by='Null counts%', ascending=False)

# Display the combined DataFrame
print(combined_info)

# %%
# Label encoding
LE=categorical1[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']]
from sklearn import preprocessing
label_enc = preprocessing.LabelEncoder()
LE=LE.apply(label_enc.fit_transform)
LE.head()

# %%
#combining both numerical data and categorical data
combined = pd.concat([Numerical_1,LE], axis=1)
combined.head()

# %%
----COORELATION MATRIX---------------------

# %%
Numerical_1_corr=combined.corr()
Numerical_2_corr=combined.corr()

Numerical_1_corr.head(100)

# %%
Numerical_1_corr.shape

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set up the matplotlib figure with a large size
plt.figure(figsize=(20, 25))  # Increased width and height

# Create a heatmap with a sky blue color map
sns.heatmap(Numerical_1_corr, annot=True, cmap='YlGnBu', vmin=-1, vmax=1, center=0, linewidths=0.5, linecolor='red')

# Title and display the plot
plt.title('Correlation Matrix Heatmap', fontsize=20)
plt.show()

# %%
#to get all corelated values but something is pending like sorting order
import pandas as pd

# Assuming `combined` is your DataFrame
# Step 1: Calculate the correlation matrix
Numerical_2_corr = combined.corr()

# Step 2: Flatten the correlation matrix and sort by absolute values in descending order
corr_pairs = Numerical_2_corr.unstack().reset_index()
corr_pairs.columns = ['Feature_1', 'Feature_2', 'Correlation']

# Filter out self-correlations (correlation of a feature with itself)
corr_pairs = corr_pairs[corr_pairs['Feature_1'] != corr_pairs['Feature_2']]

# Step 3: Sort the feature names in each row so that (Feature_1, Feature_2) and (Feature_2, Feature_1) are treated as the same pair
corr_pairs['sorted_features'] = corr_pairs.apply(lambda x: tuple(sorted([x['Feature_1'], x['Feature_2']])), axis=1)

# Step 4: Drop duplicates based on the sorted feature pairs
unique_corr_pairs = corr_pairs.drop_duplicates(subset='sorted_features').drop(columns='sorted_features')

# Step 5: Sort by absolute correlation values in descending order
sorted_corr_pairs = unique_corr_pairs.sort_values(by='Correlation', ascending=False, key=abs)

# Display the sorted and unique correlation values
print(sorted_corr_pairs.head(200))

# Step 3: Get unique columns based on sorted correlations
sorted_columns = pd.unique(sorted_corr_pairs[['Feature_1', 'Feature_2']].values.ravel('K'))
print("Columns in order of descending correlations:")
print(sorted_columns)

# %%
#storing correlation table
import pandas as pd

# Assuming Numerical_1 is your DataFrame
# Specify the path where you want to save the file
file_path = r'F:\jupyter\Numerical_1_corr.xlsx'

# Save the DataFrame as an Excel file
Numerical_1_corr.to_excel(file_path, index=False)

print(f"DataFrame saved to {file_path}")

# %%
threshold = 0.55
# Create a mask for the upper triangle
mask = np.triu(np.ones_like(Numerical_1_corr, dtype=bool))
print(mask)


tri_df = Numerical_1_corr.mask(mask)
print(tri_df)

# %%
H1=Numerical_1_corr[(Numerical_1_corr["SalePrice"]>0.3)].index.values
print(H1)

# %%
# Filter rows where "SalePrice" is greater than 0.3 and less than 0.9
filtered_corr = Numerical_1_corr[
    (Numerical_1_corr["SalePrice"] >-0.3) & (Numerical_1_corr["SalePrice"] < 0.3)
]

# Select specific columns from the filtered DataFrame
selected_columns2 = filtered_corr.index.values    #all columns
print(selected_columns2)

# %%
len(selected_columns2)

# %%
corr_table=[]
corr_table.extend(selected_columns2)
corr_table


#above code are referenced by below code
#house_train_num_cols = []
#house_train_num_cols.extend(house_train_num_corr[(house_train_num_corr["SalePrice"]<0.3) ].index.values)
#house_train_num_cols.extend(house_train_num_corr[(house_train_num_corr["SalePrice"]>-0.3) ].index.values)

# %%
#only for 4 columns logic

# Filter rows where "SalePrice" is greater than 0.3 and less than 0.9
filtered_corr = Numerical_1_corr[
    (Numerical_1_corr["SalePrice"] >-0.3) & (Numerical_1_corr["SalePrice"] < 0.3)
]

# Select specific columns from the filtered DataFrame
selected_columns = filtered_corr[["Id", "MSSubClass", "LotFrontage", "LotArea"]] # only 4 columns
selected_columns.head(100)

# %%
len(selected_columns)

# %%
#only for 4 columns logic
corr_table=[]
corr_table.extend((selected_columns).index.values)
corr_table


#above code are referenced by below code
#house_train_num_cols = []
#house_train_num_cols.extend(house_train_num_corr[(house_train_num_corr["SalePrice"]<0.3) ].index.values)
#house_train_num_cols.extend(house_train_num_corr[(house_train_num_corr["SalePrice"]>-0.3) ].index.values)

# %%
len(corr_table)

# %%
####only for reference to next step(because long jump step)
filtered_corr = Numerical_1_corr[
    (Numerical_1_corr["SalePrice"] >-0.1) & (Numerical_1_corr["SalePrice"] < 0.1)
]

# Select specific columns from the filtered DataFrame
selected_columns2 = filtered_corr.index.values    #all columns
print(selected_columns2)



corr_table=[]
corr_table.extend(selected_columns2)
corr_table

# %%
corr_table_output=Numerical_1_corr[corr_table]
corr_table_output.columns

# %%
import pandas as pd

# Assuming 'House' is your DataFrame
null_counts = corr_table_output.isnull().sum().sort_values(ascending=False)
data_types = corr_table_output.dtypes

# Combine the two into a single DataFrame and align by the sorted null counts index
combined_info = pd.DataFrame({
    'Null Count': null_counts,
    'Data Type': data_types[null_counts.index]  # Align with the sorted null counts
})

# Display the combined DataFrame
print(combined_info)

# %%
Analysis--filling before coorelation
(full null values and special characters like ? or other language words) increases columns accuracy
disadvantage-more columns can be considerable for coorelation

if we are filling null values after correlation columns 
--null vaues and special characters included .so less accuracy

# %%
corr_table_output.head()

# %%
#trying autoviz option for a file

# %%
# !pip install autoviz -q

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

from autoviz.AutoViz_Class import AutoViz_Class

# %%
filename ="C:\\Users\\chaitanya\\81 column dataset.csv"
depVar = 'SalePrice'
sep=','

# %%
AV = AutoViz_Class()

# %%
# %matplotlib inline

# %%
_ = AV.AutoViz(filename)

# %%
#trying autoviz option for only numeric data and only categorical data
not possible because sales price removed in correlation step and no sale price column in categoical data

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# Assuming corr_table_output is your existing DataFrame
# %matplotlib inline
AV = AutoViz_Class()

# Applying AutoViz to your existing DataFrame
dft = AV.AutoViz(
    filename="",  # filename is kept empty since we're passing a DataFrame
    dfte=categorical1,  # your existing DataFrame
    depVar='SalePrice' # target variable, adjust as needed
)

# %%
corr_table_output.head(100)

# %%
#Handling categorical data
